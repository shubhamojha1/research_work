# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dfas.csv")

# %%
cols_to_drop = [
    'Unnamed: 0',
    'job_name',
    'inst_id',
    'user',
    'start_date',
    'group',
#     'start_time_i', 
#     'end_time_i',
#     'start_time_j', 
#     'end_time_j'
]

# %%
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df
# Out:
#             task_name  inst_num      status  start_time      end_time  \
# 0          tensorflow       1.0  Terminated   2693235.0  2.695847e+06
# 1          tensorflow       1.0  Terminated   3399583.0  3.399732e+06
# 2          tensorflow       1.0  Terminated   2152271.0  2.158213e+06
# 3              worker     100.0      Failed   2172980.0  1.000000e+10
# 4       PyTorchWorker       4.0      Failed   2374681.0  1.000000e+10
# ...               ...       ...         ...         ...           ...
# 850028     tensorflow       1.0  Terminated   4725236.0  4.727490e+06
# 850029     tensorflow       1.0      Failed   4788805.0  1.000000e+10
# 850030     tensorflow       1.0      Failed   4800428.0  1.000000e+10
# 850031     tensorflow       1.0  Terminated   4732036.0  4.739163e+06
# 850032     tensorflow       1.0      Failed   4732294.0  1.000000e+10
#
#        gpu_type    status_j  start_time_j    end_time_j       runtime  ...  \
# 0          MISC  Terminated     2693235.0  2.695847e+06  2.612000e+03  ...
# 1          MISC  Terminated     3399583.0  3.399732e+06  1.490000e+02  ...
# 2          MISC  Terminated     2152271.0  2.158213e+06  5.942000e+03  ...
# 3          MISC      Failed     2172974.0  2.173216e+06  9.997827e+09  ...
# 4          V100      Failed     2374681.0  1.000000e+10  9.997625e+09  ...
# ...         ...         ...           ...           ...           ...  ...
# 850028     MISC  Terminated     4725236.0  4.727490e+06  2.254000e+03  ...
# 850029     P100      Failed     4788805.0  1.000000e+10  9.995211e+09  ...
# 850030     P100      Failed     4800428.0  1.000000e+10  9.995200e+09  ...
# 850031     MISC  Terminated     4732036.0  4.739163e+06  7.127000e+03  ...
# 850032     MISC      Failed     4732294.0  1.000000e+10  9.995268e+09  ...
#
#           cpu_usage  gpu_wrk_util     avg_mem  avg_gpu_wrk_mem  plan_cpu  \
# 0        350.353167     77.468451   24.306558         4.184025     600.0
# 1        117.888889      0.333333    1.870295         0.069743     600.0
# 2        139.502103      4.408403   12.811959         4.212840     600.0
# 3       4152.975415    582.481221  821.026606        20.235918   27600.0
# 4          0.000000      0.000000    0.009766         0.000000     800.0
# ...             ...           ...         ...              ...       ...
# 850028    63.042222      0.000000    3.048873         0.198406     100.0
# 850029    93.666667      0.187500    2.704799         0.157288     600.0
# 850030    73.461538      2.625000    1.946219         0.365112     600.0
# 850031  1637.419698      0.000000   15.379433         0.133434     600.0
# 850032   105.236838      0.000000   10.438064         0.133766     600.0
#
#         plan_gpu    plan_mem  cap_cpu  cap_gpu  cap_mem
# 0           50.0   29.296875     96.0      8.0    512.0
# 1          100.0   29.296875     96.0      8.0    512.0
# 2           50.0   29.296875     96.0      8.0    512.0
# 3          460.0  449.218750   4416.0    368.0  23552.0
# 4          200.0   20.000000    192.0     16.0   1024.0
# ...          ...         ...      ...      ...      ...
# 850028      25.0   29.296875     96.0      8.0    512.0
# 850029     100.0   29.296875     64.0      2.0    512.0
# 850030     100.0   29.296875     64.0      2.0    512.0
# 850031      10.0   29.296875     96.0      8.0    512.0
# 850032      10.0   29.296875     96.0      8.0    512.0
#
# [850033 rows x 27 columns]

# %%
numerical_cols = [x for x in list(df.columns) if str(df[x].dtype)!="object"]
categorical_cols = [x for x in df.columns if x not in numerical_cols]

# %%
categorical_cols
# Out:
# ['task_name', 'status', 'gpu_type', 'status_j', 'status_i', 'workload']

# %%
df['workload'].fillna('NA', inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             task_name  inst_num      status  start_time      end_time  \
# 0          tensorflow       1.0  Terminated   2693235.0  2.695847e+06
# 1          tensorflow       1.0  Terminated   3399583.0  3.399732e+06
# 2          tensorflow       1.0  Terminated   2152271.0  2.158213e+06
# 3              worker     100.0      Failed   2172980.0  1.000000e+10
# 4       PyTorchWorker       4.0      Failed   2374681.0  1.000000e+10
# ...               ...       ...         ...         ...           ...
# 850028     tensorflow       1.0  Terminated   4725236.0  4.727490e+06
# 850029     tensorflow       1.0      Failed   4788805.0  1.000000e+10
# 850030     tensorflow       1.0      Failed   4800428.0  1.000000e+10
# 850031     tensorflow       1.0  Terminated   4732036.0  4.739163e+06
# 850032     tensorflow       1.0      Failed   4732294.0  1.000000e+10
#
#        gpu_type    status_j  start_time_j    end_time_j       runtime  ...  \
# 0          MISC  Terminated     2693235.0  2.695847e+06  2.612000e+03  ...
# 1          MISC  Terminated     3399583.0  3.399732e+06  1.490000e+02  ...
# 2          MISC  Terminated     2152271.0  2.158213e+06  5.942000e+03  ...
# 3          MISC      Failed     2172974.0  2.173216e+06  9.997827e+09  ...
# 4          V100      Failed     2374681.0  1.000000e+10  9.997625e+09  ...
# ...         ...         ...           ...           ...           ...  ...
# 850028     MISC  Terminated     4725236.0  4.727490e+06  2.254000e+03  ...
# 850029     P100      Failed     4788805.0  1.000000e+10  9.995211e+09  ...
# 850030     P100      Failed     4800428.0  1.000000e+10  9.995200e+09  ...
# 850031     MISC  Terminated     4732036.0  4.739163e+06  7.127000e+03  ...
# 850032     MISC      Failed     4732294.0  1.000000e+10  9.995268e+09  ...
#
#           cpu_usage  gpu_wrk_util     avg_mem  avg_gpu_wrk_mem  plan_cpu  \
# 0        350.353167     77.468451   24.306558         4.184025     600.0
# 1        117.888889      0.333333    1.870295         0.069743     600.0
# 2        139.502103      4.408403   12.811959         4.212840     600.0
# 3       4152.975415    582.481221  821.026606        20.235918   27600.0
# 4          0.000000      0.000000    0.009766         0.000000     800.0
# ...             ...           ...         ...              ...       ...
# 850028    63.042222      0.000000    3.048873         0.198406     100.0
# 850029    93.666667      0.187500    2.704799         0.157288     600.0
# 850030    73.461538      2.625000    1.946219         0.365112     600.0
# 850031  1637.419698      0.000000   15.379433         0.133434     600.0
# 850032   105.236838      0.000000   10.438064         0.133766     600.0
#
#         plan_gpu    plan_mem  cap_cpu  cap_gpu  cap_mem
# 0           50.0   29.296875     96.0      8.0    512.0
# 1          100.0   29.296875     96.0      8.0    512.0
# 2           50.0   29.296875     96.0      8.0    512.0
# 3          460.0  449.218750   4416.0    368.0  23552.0
# 4          200.0   20.000000    192.0     16.0   1024.0
# ...          ...         ...      ...      ...      ...
# 850028      25.0   29.296875     96.0      8.0    512.0
# 850029     100.0   29.296875     64.0      2.0    512.0
# 850030     100.0   29.296875     64.0      2.0    512.0
# 850031      10.0   29.296875     96.0      8.0    512.0
# 850032      10.0   29.296875     96.0      8.0    512.0
#
# [823234 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['task_name', 'inst_num', 'status', 'start_time', 'end_time', 'gpu_type',
#        'status_j', 'start_time_j', 'end_time_j', 'runtime', 'status_i',
#        'start_time_i', 'end_time_i', 'runtime_i', 'duration_min', 'wait_time',
#        'workload', 'cpu_usage', 'gpu_wrk_util', 'avg_mem', 'avg_gpu_wrk_mem',
#        'plan_cpu', 'plan_gpu', 'plan_mem', 'cap_cpu', 'cap_gpu', 'cap_mem'],
#       dtype='object')

# %%
df['start_time_i']
# Out:
# 0         2693240.0
# 1         3399681.0
# 2         2152280.0
# 3         2172995.0
# 4         2374699.0
#             ...
# 850028    4725241.0
# 850029    4788815.0
# 850030    4800441.0
# 850031    4733523.0
# 850032    4736686.0
# Name: start_time_i, Length: 823234, dtype: float64

# %%
df['start_time_']
